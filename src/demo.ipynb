# %% [markdown]
# ## Inverse Cooking: Recipe Generation from Food Images

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (0.21.0)
# Requirement already satisfied: filelock in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mufad\anaconda3\envs\trainmodel_env\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
import os
from args import get_parser
import pickle
from model import get_model
from torchvision import transforms
from utils.output_utils import prepare_output
from PIL import Image
import time

# %% [markdown]
# Set ```data_dir``` to the path including vocabularies and model checkpoint

# %%
data_dir = '../data'

# %%
# code will run in gpu if available and if the flag is set to True, else it will run on cpu
use_gpu = False
device = torch.device('cuda' if torch.cuda.is_available() and use_gpu else 'cpu')
map_loc = None if torch.cuda.is_available() and use_gpu else 'cpu'

# %%
# code below was used to save vocab files so that they can be loaded without Vocabulary class
#ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_ingrs.pkl'), 'rb'))
#ingrs_vocab = [min(w, key=len) if not isinstance(w, str) else w for w in ingrs_vocab.idx2word.values()]
#vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_toks.pkl'), 'rb')).idx2word
#pickle.dump(ingrs_vocab, open('../demo/ingr_vocab.pkl', 'wb'))
#pickle.dump(vocab, open('../demo/instr_vocab.pkl', 'wb'))

ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'ingr_vocab.pkl'), 'rb'))
vocab = pickle.load(open(os.path.join(data_dir, 'instr_vocab.pkl'), 'rb'))

ingr_vocab_size = len(ingrs_vocab)
instrs_vocab_size = len(vocab)
output_dim = instrs_vocab_size

# %%
print (instrs_vocab_size, ingr_vocab_size)
# Out:
# 23231 1488

# %%
t = time.time()
import sys
sys.argv = ['']
del sys
import os
import pickle  # <-- THIS IS CRUCIAL

# Load vocabularies DIRECTLY from pickle files
with open('../data/ingr_vocab.pkl', 'rb') as f:
    ingr_vocab = pickle.load(f)
    
with open('../data/instr_vocab.pkl', 'rb') as f:
    instr_vocab = pickle.load(f)

# Rest of your existing code
args = get_parser()
args.maxseqlen = 15
args.ingrs_only=False
model = get_model(args, len(ingr_vocab), len(instr_vocab))  # Use actual vocab sizes

# Load model weights
model_path = os.path.join(data_dir, 'modelbest.ckpt')
model.load_state_dict(torch.load(model_path, map_location=map_loc))
model.to(device)
model.eval()

# Save FULL model
save_path = 'saved_model.pth'
torch.save({
    'model_state': model.state_dict(),
    'ingr_vocab': ingr_vocab,
    'instr_vocab': instr_vocab,
    'args': args
}, save_path)

print(f"Model saved to {save_path}")
print("Elapsed time:", time.time() -t)
# Out:
# C:\Users\mufad\anaconda3\envs\trainModel_env\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mufad\anaconda3\envs\trainModel_env\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\Users\mufad\anaconda3\envs\trainModel_env\lib\site-packages\torch\nn\_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Model saved to saved_model.pth
# Elapsed time: 1.79298996925354

# %%
transf_list_batch = []
transf_list_batch.append(transforms.ToTensor())
transf_list_batch.append(transforms.Normalize((0.485, 0.456, 0.406), 
                                              (0.229, 0.224, 0.225)))
to_input_transf = transforms.Compose(transf_list_batch)

# %%
greedy = [True, False, False, False]
beam = [-1, -1, -1, -1]
temperature = 1.0
numgens = len(greedy)

# %% [markdown]
# Set ```use_urls = True``` to get recipes for images in ```demo_urls```.
#
# You can also set ```use_urls = False``` and get recipes for images in the path in ```data_dir/test_imgs```.

# %%
import requests
from io import BytesIO
import random
from collections import Counter
use_urls = False # set to true to load images from demo_urls instead of those in test_imgs folder
show_anyways = False #if True, it will show the recipe even if it's not valid
image_folder = os.path.join(data_dir, 'demo_imgs')

if not use_urls:
    demo_imgs = os.listdir(image_folder)
    random.shuffle(demo_imgs)

demo_urls = ['https://food.fnr.sndimg.com/content/dam/images/food/fullset/2013/12/9/0/FNK_Cheesecake_s4x3.jpg.rend.hgtvcom.826.620.suffix/1387411272847.jpeg',
            'https://www.196flavors.com/wp-content/uploads/2014/10/california-roll-3-FP.jpg']

demo_files = demo_urls if use_urls else demo_imgs

# %%
for img_file in demo_files:
    
    if use_urls:
        response = requests.get(img_file)
        image = Image.open(BytesIO(response.content))
    else:
        image_path = os.path.join(image_folder, img_file)
        image = Image.open(image_path).convert('RGB')
    
    transf_list = []
    transf_list.append(transforms.Resize(256))
    transf_list.append(transforms.CenterCrop(224))
    transform = transforms.Compose(transf_list)
    
    image_transf = transform(image)
    image_tensor = to_input_transf(image_transf).unsqueeze(0).to(device)
    
    plt.imshow(image_transf)
    plt.axis('off')
    plt.show()
    plt.close()
    
    num_valid = 1
    for i in range(numgens):
        with torch.no_grad():
            outputs = model.sample(image_tensor, greedy=greedy[i], 
                                   temperature=temperature, beam=beam[i], true_ingrs=None)
            
        ingr_ids = outputs['ingr_ids'].cpu().numpy()
        recipe_ids = outputs['recipe_ids'].cpu().numpy()
            
        outs, valid = prepare_output(recipe_ids[0], ingr_ids[0], ingrs_vocab, vocab)
        
        if valid['is_valid'] or show_anyways:
            
            print ('RECIPE', num_valid)
            num_valid+=1
            #print ("greedy:", greedy[i], "beam:", beam[i])
    
            BOLD = '\033[1m'
            END = '\033[0m'
            print (BOLD + '\nTitle:' + END,outs['title'])

            print (BOLD + '\nIngredients:'+ END)
            print (', '.join(outs['ingrs']))

            print (BOLD + '\nInstructions:'+END)
            print ('-'+'\n-'.join(outs['recipe']))

            print ('='*20)

        else:
            pass
            print ("Not a valid recipe!")
            print ("Reason: ", valid['reason'])
# Out:
# RECIPE 1
#
# Title: Chicken enchiladas
#
# Ingredients:
# cheese, tortilla, onion, cream, enchilada_sauce, chicken, chili, beans, pepper, tomato, cumin
#
# Instructions:
# -Preheat oven to 350 degrees.
# -In a large bowl, combine chicken, beans, tomatoes, onion, green chilies, cumin, and chili powder.
# -Spoon about 1/4 cup of the chicken mixture down the center of each tortilla.
# -Roll up and place seam side down in a greased 13x9 baking dish.
# -Pour enchilada sauce over enchiladas.
# -Sprinkle with cheese.
# -Bake uncovered for 20 minutes.
# ====================
# RECIPE 2
#
# Title: Chicken enchiladas
#
# Ingredients:
# cheese, tortilla, onion, cream, enchilada_sauce, chicken, chili, beans, pepper, tomato, cumin
#
# Instructions:
# -In large bowl combine chicken, beans, tomato sauce, green chilies, green onions, cumin, chili powder and salt and pepper to taste.
# -In a 13x9 pan lay tortillas flat, fill each one with filling, and fold to cover.
# -Place enchiladas seam side down in pan.
# -Cover with enchilada sauce and sprinkle with cheese.
# -Bake at 350 degrees for 20 minutes.
# ====================
# RECIPE 3
#
# Title: Chicken chili enchiladas
#
# Ingredients:
# cheese, tortilla, onion, cream, enchilada_sauce, chicken, chili, beans, pepper, tomato, cumin
#
# Instructions:
# -Cook onions in large skillet sprayed with no stick cooking spray on medium heat 5 min.
# -Or until tender, stirring occasionally.
# -Stir in chicken, beans and next 5 ingredients; simmer 7 min., stirring occasionally.
# -Spoon down centers of tortillas; roll up.
# -Place, seam sides down, in 2-qt.
# -Baking dish sprayed with cooking spray; top with remaining ingredients.
# -Cover.
# -Refrigerate up to 2 days.
# -Heat oven to 375 degrees f. bake, uncovered, 25 min.
# -Or until heated through.
# ====================
# RECIPE 4
#
# Title: Chicken enchilada casserole
#
# Ingredients:
# cheese, tortilla, onion, cream, enchilada_sauce, chicken, chili, beans, pepper, tomato, cumin
#
# Instructions:
# -Preheat oven to 350 degrees.
# -Brown chicken, onion and bell pepper.
# -In a bowl, mix together enchilada sauce, cream cheese, sour cream and chili powder.
# -Layer 1/3 of the chicken (broken down into pieces so they fit in a 9x13 baking dish), 1 cup of the bean sauce, 1/2 of cheese, 1/2 cup of the enchilada sauce, 1/4 of the shredded chicken, 1/4 cup of cheese, half of the green chiles, and 1/2 cup of the cheese.
# -Repeat layers.
# -Bake at 350 degrees for 30 to 40 minutes.
# ====================
# RECIPE 1
#
# Title: Grilled eggplant and zucchini
#
# Ingredients:
# zucchini, oil, salt, eggplant, pepper
#
# Instructions:
# -Preheat grill to medium-high.
# -Brush eggplant slices with oil and season with salt and pepper.
# -Grill, turning once, until tender and lightly charred, about 10 minutes.
# -Transfer to a platter and let cool.
# -Cut into 1/2-inch slices.
# -Serve warm.
# ====================
# RECIPE 2
#
# Title: Zucchini and eggplant
#
# Ingredients:
# zucchini, oil, salt, eggplant, pepper
#
# Instructions:
# -Slice the eggplants.
# -Heat the oil, add the eggplants, fry them over medium heat until browned.
# -Add the salt, cover them with a lid, turn them over once they become soft and cook until they become soft.
# ====================
# RECIPE 3
#
# Title: Grilled eggplant, zucchini and sea salt
#
# Ingredients:
# zucchini, oil, salt, eggplant, pepper
#
# Instructions:
# -Prepare grill for cooking and oil grate.
# -Grill the eggplant and sea salt over medium-high heat until tender, about 5 minutes.
# -Remove from the grill and let cool slightly.
# -Slice in half lengthwise to make 3 long strips.
# -In a small glass bowl, toss together with olive oil, salt and pepper and grill until lightly browned.
# -Serve on a platter and enjoy.
# ====================
# RECIPE 4
#
# Title: Microwave-steamed zucchini
#
# Ingredients:
# zucchini, oil, salt, eggplant, pepper
#
# Instructions:
# -Preheat the oven to 200c.
# -Cut the stem end off the zucchini, then cut each in half lengthwise.
# -Scoop the inside out so the shells are flat (about 3/4 of the way).
# -Place in a large bowl and pour the olive oil over the eggplant.
# -Place the bowl in the microwave and cook for about 1 minute, until tender and browned.
# -Once cool enough to handle, squeeze out any excess oil.
# -Season the zucchini with salt and pepper.
# -Serve immediately.
# ====================
# RECIPE 1
#
# Title: Garlic shrimp scampi
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -Heat olive oil in a large skillet over medium heat.
# -Cook and stir garlic in hot oil until fragrant, about 1 minute.
# -Stir shrimp into garlic; cook and stir until shrimp are pink and opaque, about 3 minutes.
# -Season with salt and pepper.
# -Stir butter into shrimp mixture until melted and sauce is heated through, about 2 minutes.
# -Stir parsley into shrimp mixture; cook and stir until heated through, about 1 minute.
# ====================
# RECIPE 2
#
# Title: Fettuccine
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -Melt the butter and oil over medium heat.
# -Add the garlic and parsley.
# -Add the shrimp and saute for 4 to 5 minutes or until they turn pink.
# -Add the salt, pepper and the pasta.
# -Serve.
# ====================
# RECIPE 3
#
# Title: Garlic shrimp with butter
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -Heat oil in a large skillet over medium-high heat.
# -Stir in garlic, parsley, seasoned salt, and red pepper flakes.
# -Add shrimp to skillet and cook until shrimp turn pink and are heated through, about 5 minutes.
# -Serve shrimp on a bed of fettuccine.
# ====================
# RECIPE 4
#
# Title: Garlic and herb angel hair pasta with shrimp (aglio e olio e peperoncino)
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -Put garlic and olive oil in a frying pan and turn on the heat.
# -When it starts to sizzle, add the shrimp, and cook until they turn pink.
# -When they are done, add the red pepper flakes and salt to taste.
# -Remove from heat after it has completely cooled.
# -Boil plenty of water and cook the pasta.
# -Add the boiled pasta to the frying pan and stir quickly.
# -Add the butter and stir.
# -Sprinkle black pepper over the pasta and mix lightly.
# -It's done when the pasta is al dente and it's done !
# -Add black pepper and parsley to taste, and serve immediately !
# ====================
# RECIPE 1
#
# Title: Penne with caramelized onions
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Heat oil in large skillet over medium-high heat.
# -Add onions; cook until golden brown, stirring occasionally, about 15 minutes.
# -Add pasta and cook until heated through, stirring occasionally, about 10 minutes.
# -Season with salt and pepper.
# -Sprinkle with cheese.
# ====================
# RECIPE 2
#
# Title: Ziti with roasted peppers & mozzarella
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Cut onion into quarters, peel, cut into thin strips, and set aside.
# -Boil shells as directed on package, drain and set aside.
# -In a large skillet heat olive oil, add peppers, onions and saute over medium heat until they begin to soften, about 15 minutes.
# -Season with salt and pepper to taste, add the pasta and toss.
# -Serve immediately.
# -Top with shaved pecorino romano cheese and freshly grated parmesan cheese.
# ====================
# RECIPE 3
#
# Title: Ziti in a skillet
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Cut onion into wedges.
# -Saute onion in a little oil.
# -Add pasta and toss until pasta is coated with the oil.
# -Add the rest of the ingredients and toss lightly.
# -Add the cheeses, toss gently to coat and serve warm.
# ====================
# RECIPE 4
#
# Title: Penne alla marlboro country (aka monday night)
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Put olive oil in a lrg frying pan over med heat.
# -Add onions and season with a little salt and black pepper (to taste).
# -Stir to coat onions.
# -Let onions begin to soften.
# -Turn heat down to medium low and allow onions to sweat for a bit.
# -Add pasta and stir for about 2-3 minutes until pasta is slightly softened.
# -Then pour in a sml amt of water.
# -Stir until pasta is well coated and the water is absorbed.
# -Remove from the heat and stir in the mozzarella cheese.
# -Add chopped red peppers (if desired).
# -Let stand for 5 minutes before serving.
# -Serves 6-8 as a main course.
# -Enjoy !
# ====================
# RECIPE 1
#
# Title: Easy pancakes
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -Mix all ingredients together.
# -Heat skillet and pour 1/4 cup of batter onto skillet.
# -Cook until bubbles form on top.
# -Flip and cook until golden brown.
# ====================
# RECIPE 2
#
# Title: Peanut butter bars
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -Preheat oven to 350f.
# -Line a 13 x 9 inch pan with a foil and grease the foil.
# -In a mixing bowl, combine peanut butter and sugar; beat uintil creamy.
# -Add the eggs, oil, milk, and salt; beat well.
# -Stir in flour and baking powder.
# -Spread into prepared pan.
# -Bake for 20-25 minutes or until top springs back but do n't turn out.
# -Remove bars from pan and cool completely.
# -Cut into bars.
# ====================
# RECIPE 3
#
# Title: Peanut butter pie crust
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -Preheat oven to 400f.
# -Whisk together flour, salt, and baking powder.
# -Cut in oil, peanut butter with a pastry cutter or 2 knives until mixture looks like coarse meal, then stir in milk and egg.
# -Turn out onto lightly floured surface and gently knead until dough just holds together.
# -Roll out dough into a 12-inch circle and fit into a 10-inch pie plate.
# -Crimp edges to seal.
# -Cut into 9 wedges; place on baking sheet and brush with oil.
# -Bake until golden, about 15 minutes.
# -Cool on wire rack.
# -Serve warm or at room temperature.
# -Garnish with additional peanut butter, if desired.
# ====================
# RECIPE 4
#
# Title: Crepes
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -.mix all the dry ingredients together.
# -Add the melted butter and mix again.
# -In a pan add oil and add 1/2 cup of batter and tilt to spread the batter to coat the bottom of pan.
# -When you see the bottom and sides start to brown turn it over and cook on a low to medium heat.
# -Repeat until all crepe batter is cooked.
# -Place on a plate and sprinkle some of the sugar to taste.
# -Top with syrup and enjoy:) !
# ====================
# RECIPE 1
#
# Title: Avocado egg salad sandwich
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Toast bread.
# -Spread mayonnaise on one side of each slice.
# -Place avocado slices on one slice of bread.
# -Top with tomato slices and salt and pepper.
# -Top with other slice of bread.
# ====================
# RECIPE 2
#
# Title: Avocado egg sandwich
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Slice avocado into half the seed
# -Toast bread
# -Put mayo and egg on bread then put tomato then add salt and pepper as you like
# ====================
# RECIPE 3
#
# Title: Avocado and egg sandwich
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Slice the avocado, tomato, and egg
# -Season with pepper and salt
# -Serve on bread, toast, and mayonnaise on both sides
# ====================
# RECIPE 4
#
# Title: Easy and cute ! avocado toast
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Slice the avocado, put it into a bowl, mash up well and mash up with a fork.
# -Add the salt, pepper, and mayonnaise, and mix well until smooth.
# -Toast the bread lightly.
# -Spread the avocado on the toast, then add the egg mixture, then top with tomato, and it's done.
# ====================
